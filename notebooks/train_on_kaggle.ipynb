# %% [markdown]
# # 🎮 DQN Agent Training for Atari Pong
#
# This notebook trains a Deep Q-Network (DQN) agent to play Atari Pong.
#
# ## Quick Start
# 1. **Enable GPU**: Settings → Accelerator → GPU T4 x2 or P100
# 2. **Run all cells**: Run → Run All
# 3. **Download model**: Use the Output tab to download `final_model.pth`
#
# ---

# %% [markdown]
# ## 📦 Step 1: Install Dependencies

# %%
# Install dependencies
# !pip install -q gymnasium[atari,accept-rom-license] shimmy[atari] ale-py
# !pip install -q opencv-python torch torchvision

# Verify GPU
import torch
print(f"\n🔧 PyTorch version: {torch.__version__}")
print(f"🎮 GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"   Device: {torch.cuda.get_device_name(0)}")
else:
    print("⚠️ WARNING: No GPU detected! Enable GPU in Settings → Accelerator")
# Out:
# WARNING: shimmy 2.0.0 does not provide the extra 'atari'
# WARNING: gymnasium 1.2.3 does not provide the extra 'accept-rom-license'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 15.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-baselines3 2.1.0 requires gymnasium<0.30,>=0.28.1, but you have gymnasium 1.2.3 which is incompatible.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 1.2.3 which is incompatible.
#
# 🔧 PyTorch version: 2.8.0+cu126
# 🎮 GPU Available: True
#    Device: Tesla T4

# %% [markdown]
# ## 🧠 Step 2: Define Neural Network

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import random
import os

class AtariCNN(nn.Module):
    """Nature DQN CNN - 3 conv layers + 2 FC layers"""
    def __init__(self, action_dim):
        super(AtariCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(4, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )
        self.fc = nn.Sequential(
            nn.Linear(64 * 7 * 7, 512),
            nn.ReLU(),
            nn.Linear(512, action_dim)
        )

    def forward(self, x):
        x = x.float() / 255.0
        x = self.features(x)
        x = x.reshape(x.size(0), -1)
        return self.fc(x)

print("✅ AtariCNN defined")
# Out:
# ✅ AtariCNN defined

# %% [markdown]
# ## 💾 Step 3: Experience Replay Buffer

# %%
class ExperienceReplayBuffer:
    """Circular buffer with pre-allocated numpy arrays"""
    def __init__(self, capacity, state_shape):
        self.capacity = capacity
        self.ptr = 0
        self.size = 0
        
        self.states = np.zeros((capacity, *state_shape), dtype=np.uint8)
        self.actions = np.zeros(capacity, dtype=np.int64)
        self.rewards = np.zeros(capacity, dtype=np.float32)
        self.next_states = np.zeros((capacity, *state_shape), dtype=np.uint8)
        self.dones = np.zeros(capacity, dtype=np.bool_)

    def push(self, state, action, reward, next_state, done):
        self.states[self.ptr] = state
        self.actions[self.ptr] = action
        self.rewards[self.ptr] = reward
        self.next_states[self.ptr] = next_state
        self.dones[self.ptr] = done
        self.ptr = (self.ptr + 1) % self.capacity
        self.size = min(self.size + 1, self.capacity)

    def sample(self, batch_size):
        indices = np.random.choice(self.size, batch_size, replace=False)
        return (
            torch.from_numpy(self.states[indices]),
            torch.from_numpy(self.actions[indices]),
            torch.from_numpy(self.rewards[indices]),
            torch.from_numpy(self.next_states[indices]),
            torch.from_numpy(self.dones[indices])
        )
    
    def __len__(self):
        return self.size

print("✅ ExperienceReplayBuffer defined")
# Out:
# ✅ ExperienceReplayBuffer defined

# %% [markdown]
# ## 🤖 Step 4: DQN Agent

# %%
class DQNAgent:
    def __init__(self, model_class, action_dim, device, lr=1e-4, gamma=0.99,
                 epsilon_start=1.0, epsilon_final=0.01, epsilon_decay=1000000):
        self.action_dim = action_dim
        self.device = device
        self.gamma = gamma
        
        self.epsilon = epsilon_start
        self.epsilon_final = epsilon_final
        self.epsilon_decay = epsilon_decay
        self.steps_done = 0

        self.policy_net = model_class(action_dim).to(device)
        self.target_net = model_class(action_dim).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)

    def select_action(self, state):
        self.epsilon = max(self.epsilon_final,
                           1.0 - (self.steps_done / self.epsilon_decay))
        self.steps_done += 1

        if random.random() > self.epsilon:
            with torch.no_grad():
                state_t = torch.tensor(state, device=self.device).unsqueeze(0)
                return self.policy_net(state_t).argmax().item()
        else:
            return random.randrange(self.action_dim)

    def update_model(self, experiences):
        states, actions, rewards, next_states, dones = experiences
        
        states = states.to(self.device)
        actions = actions.to(self.device).unsqueeze(1)
        rewards = rewards.to(self.device)
        next_states = next_states.to(self.device)
        dones = dones.to(self.device).float()

        rewards = torch.clamp(rewards, -1.0, 1.0)
        current_q = self.policy_net(states).gather(1, actions)
        avg_q = current_q.mean().item()

        with torch.no_grad():
            max_next_q = self.target_net(next_states).max(1)[0]
            target_q = rewards + (self.gamma * max_next_q * (1 - dones))

        loss = F.smooth_l1_loss(current_q.squeeze(), target_q)

        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 1.0)
        self.optimizer.step()

        return loss.item(), avg_q

    def sync_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

print("✅ DQNAgent defined")
# Out:
# ✅ DQNAgent defined

# %% [markdown]
# ## 🎮 Step 5: Environment Wrappers

# %%
import gymnasium as gym
from gymnasium import spaces
import cv2
import ale_py

gym.register_envs(ale_py)

class AtariPreprocessing(gym.Wrapper):
    def __init__(self, env, screen_size=84):
        super().__init__(env)
        self.screen_size = screen_size
        self.observation_space = spaces.Box(
            low=0, high=255, shape=(screen_size, screen_size, 1), dtype=np.uint8
        )

    def step(self, action):
        total_reward = 0.0
        terminated = truncated = False
        frame_buffer = np.zeros((2, 210, 160, 3), dtype=np.uint8)
        
        for i in range(4):
            obs, reward, term, trunc, info = self.env.step(action)
            if i >= 2:
                frame_buffer[i - 2] = obs
            total_reward += float(reward)
            terminated = terminated or term
            truncated = truncated or trunc
            if terminated or truncated:
                break
        
        max_frame = frame_buffer.max(axis=0)
        return self._preprocess(max_frame), total_reward, terminated, truncated, info

    def _preprocess(self, frame):
        img = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        img = cv2.resize(img, (self.screen_size, self.screen_size))
        return img[:, :, np.newaxis]

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return self._preprocess(obs), info


class FrameStack(gym.Wrapper):
    def __init__(self, env, k=4):
        super().__init__(env)
        self.k = k
        self.frames = []
        shp = env.observation_space.shape
        self.observation_space = spaces.Box(
            low=0, high=255, shape=(k, shp[0], shp[1]), dtype=np.uint8
        )

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self.frames = [obs for _ in range(self.k)]
        return self._get_ob(), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        self.frames.pop(0)
        self.frames.append(obs)
        return self._get_ob(), reward, terminated, truncated, info

    def _get_ob(self):
        return np.stack(self.frames, axis=0).squeeze()


def make_atari_env(game_id):
    env = gym.make(game_id)
    env = AtariPreprocessing(env)
    env = FrameStack(env, k=4)
    return env

print("✅ Environment wrappers defined")
# Out:
# ✅ Environment wrappers defined

# %% [markdown]
# ## 🔄 Step 6: Check for Existing Checkpoint

# %%
import glob

# Kaggle uses /kaggle/working for outputs
SAVE_DIR = '/kaggle/working'
os.makedirs(SAVE_DIR, exist_ok=True)

def find_latest_checkpoint():
    """Find the most recent checkpoint in working dir, datasets, OR models."""
    all_checkpoints = []
    
    # Search in /kaggle/working (current session)
    all_checkpoints.extend(glob.glob('/kaggle/working/checkpoint_*.pth'))
    all_checkpoints.extend(glob.glob('/kaggle/working/final_model.pth'))
    
    # Search in /kaggle/input (datasets AND models - recursive search finds both!)
    all_checkpoints.extend(glob.glob('/kaggle/input/**/checkpoint_*.pth', recursive=True))
    all_checkpoints.extend(glob.glob('/kaggle/input/**/final_model.pth', recursive=True))
    
    if not all_checkpoints:
        return None, 0
    
    def get_step(path):
        if 'final_model' in path:
            return float('inf')  # Final model takes priority
        try:
            return int(path.split('_')[-1].replace('.pth', ''))
        except:
            return 0
    
    latest = max(all_checkpoints, key=get_step)
    step = get_step(latest) if get_step(latest) != float('inf') else 0
    return latest, step

latest_checkpoint, resume_step = find_latest_checkpoint()

if latest_checkpoint:
    print(f"🔄 Found checkpoint: {latest_checkpoint}")
    if '/kaggle/input/' in latest_checkpoint:
        print(f"   📦 Source: Uploaded Dataset/Model")
    else:
        print(f"   📁 Source: Current Session")
    print(f"   Training will resume from step {resume_step:,}")
else:
    print("🆕 No checkpoint found. Training will start from scratch.")
    print("   Tip: Upload checkpoints as a Dataset or Model to resume across sessions!")
# Out:
# 🔄 Found checkpoint: /kaggle/input/atari-dqn-5m/pytorch/default/1/checkpoint_5000000.pth
#    📦 Source: Uploaded Dataset/Model
#    Training will resume from step 5,000,000

# %% [markdown]
# ## 🚀 Step 7: Training Loop

# %%
from collections import deque
import time

def train(save_dir, resume_from=None):
    # ========== Configuration ==========
    GAME_ID = "ALE/Pong-v5"
    BATCH_SIZE = 32
    LR = 1e-4
    GAMMA = 0.99
    REPLAY_SIZE = 100000
    TARGET_UPDATE_FREQ = 10000
    TOTAL_STEPS = 8000000      # ⬆️ 5M steps for better results
    CHECKPOINT_FREQ = 100000   # ⬆️ Checkpoint every 100k steps
    EARLY_STOP_REWARD = 18.0
    SESSION_LIMIT_HOURS = 11.5  # Warn before 12h Kaggle limit
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"🎮 Training on: {device}")
    
    env = make_atari_env(GAME_ID)
    agent = DQNAgent(AtariCNN, env.action_space.n, device, lr=LR, gamma=GAMMA)
    buffer = ExperienceReplayBuffer(REPLAY_SIZE, env.observation_space.shape)
    
    start_step = 1
    
    # Resume from checkpoint if available
    if resume_from and os.path.exists(resume_from):
        print(f"\n🔄 Loading checkpoint: {resume_from}")
        checkpoint = torch.load(resume_from, map_location=device)
        agent.policy_net.load_state_dict(checkpoint['model_state_dict'])
        agent.target_net.load_state_dict(checkpoint['model_state_dict'])
        agent.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        agent.epsilon = checkpoint['epsilon']
        agent.steps_done = checkpoint.get('steps_done', checkpoint['step'])
        start_step = checkpoint['step'] + 1
        print(f"✅ Resumed from step {start_step:,}, epsilon={agent.epsilon:.4f}")
    
    state, _ = env.reset()
    episode_rewards = deque(maxlen=100)
    current_episode_reward = 0
    start_time = time.time()
    
    print(f"\n{'='*50}")
    print(f"🚀 Training started! Target: avg reward ≥ {EARLY_STOP_REWARD}")
    print(f"   Steps: {start_step:,} → {TOTAL_STEPS:,}")
    print(f"{'='*50}\n")
    
    for step in range(start_step, TOTAL_STEPS + 1):
        action = agent.select_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        current_episode_reward += reward
        
        buffer.push(state, action, reward, next_state, done)
        state = next_state
        
        if len(buffer) > BATCH_SIZE:
            experiences = buffer.sample(BATCH_SIZE)
            loss, _ = agent.update_model(experiences)
        
        if step % TARGET_UPDATE_FREQ == 0:
            agent.sync_target_network()
        
        if done:
            episode_rewards.append(current_episode_reward)
            avg_reward = np.mean(episode_rewards)
            
            if len(episode_rewards) % 10 == 0:
                elapsed_hours = (time.time() - start_time) / 3600
                print(f"Step {step:>8,} | Avg Reward: {avg_reward:>6.1f} | "
                      f"Epsilon: {agent.epsilon:.3f} | Time: {elapsed_hours:.1f}h")
                
                # ⚠️ Session limit warning
                if elapsed_hours >= SESSION_LIMIT_HOURS:
                    print(f"\n⚠️ APPROACHING 12H LIMIT! Saving checkpoint...")
                    checkpoint_path = os.path.join(save_dir, f'checkpoint_{step}.pth')
                    torch.save({
                        'step': step,
                        'model_state_dict': agent.policy_net.state_dict(),
                        'optimizer_state_dict': agent.optimizer.state_dict(),
                        'epsilon': agent.epsilon,
                        'steps_done': agent.steps_done
                    }, checkpoint_path)
                    print(f"💾 Emergency checkpoint: {checkpoint_path}")
                    print(f"   Download this from Output tab before session ends!")
            
            if len(episode_rewards) == 100 and avg_reward >= EARLY_STOP_REWARD:
                print(f"\n🎉 GOAL REACHED! Average reward: {avg_reward:.1f}")
                final_path = os.path.join(save_dir, 'final_model.pth')
                torch.save({
                    'step': step,
                    'model_state_dict': agent.policy_net.state_dict(),
                    'optimizer_state_dict': agent.optimizer.state_dict(),
                    'epsilon': agent.epsilon,
                    'steps_done': agent.steps_done
                }, final_path)
                print(f"💾 Final model saved to: {final_path}")
                return final_path
            
            state, _ = env.reset()
            current_episode_reward = 0
        
        if step % CHECKPOINT_FREQ == 0:
            checkpoint_path = os.path.join(save_dir, f'checkpoint_{step}.pth')
            torch.save({
                'step': step,
                'model_state_dict': agent.policy_net.state_dict(),
                'optimizer_state_dict': agent.optimizer.state_dict(),
                'epsilon': agent.epsilon,
                'steps_done': agent.steps_done
            }, checkpoint_path)
            print(f"💾 Checkpoint saved: {checkpoint_path}")
    
    # Save final model
    final_path = os.path.join(save_dir, 'final_model.pth')
    torch.save({
        'step': step,
        'model_state_dict': agent.policy_net.state_dict(),
        'optimizer_state_dict': agent.optimizer.state_dict(),
        'epsilon': agent.epsilon,
        'steps_done': agent.steps_done
    }, final_path)
    
    print(f"\n{'='*50}")
    print(f"✅ Training complete!")
    print(f"   Final avg reward: {np.mean(episode_rewards):.1f}")
    print(f"   Model saved to: {final_path}")
    print(f"{'='*50}")
    
    return final_path

print("✅ Training function defined!")
# Out:
# ✅ Training function defined!

# %% [markdown]
# ## 🎮 Step 8: START TRAINING!

# %%
# 🎮 START TRAINING!
final_model_path = train(SAVE_DIR, resume_from=latest_checkpoint)
# Out:
# 🎮 Training on: cuda
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# 🔄 Loading checkpoint: /kaggle/input/atari-dqn-5m/pytorch/default/1/checkpoint_5000000.pth
# ✅ Resumed from step 5,000,001, epsilon=0.0100
#
# ==================================================
# 🚀 Training started! Target: avg reward ≥ 18.0
#    Steps: 5,000,001 → 8,000,000
# ==================================================
#
# Step 5,009,496 | Avg Reward:    2.8 | Epsilon: 0.010 | Time: 0.0h
# Step 5,018,520 | Avg Reward:    5.0 | Epsilon: 0.010 | Time: 0.0h
# Step 5,027,899 | Avg Reward:    4.7 | Epsilon: 0.010 | Time: 0.1h
# Step 5,036,901 | Avg Reward:    5.5 | Epsilon: 0.010 | Time: 0.1h
# Step 5,045,343 | Avg Reward:    5.6 | Epsilon: 0.010 | Time: 0.1h
# Step 5,054,197 | Avg Reward:    6.0 | Epsilon: 0.010 | Time: 0.1h
# Step 5,063,043 | Avg Reward:    6.2 | Epsilon: 0.010 | Time: 0.1h
# Step 5,071,480 | Avg Reward:    6.6 | Epsilon: 0.010 | Time: 0.2h
# Step 5,080,496 | Avg Reward:    6.7 | Epsilon: 0.010 | Time: 0.2h
# Step 5,088,746 | Avg Reward:    7.1 | Epsilon: 0.010 | Time: 0.2h
# Step 5,089,572 | Avg Reward:    7.3 | Epsilon: 0.010 | Time: 0.2h
# Step 5,090,500 | Avg Reward:    7.3 | Epsilon: 0.010 | Time: 0.2h
# Step 5,091,376 | Avg Reward:    7.4 | Epsilon: 0.010 | Time: 0.2h
# Step 5,092,258 | Avg Reward:    7.5 | Epsilon: 0.010 | Time: 0.2h
# Step 5,093,164 | Avg Reward:    7.5 | Epsilon: 0.010 | Time: 0.2h
# Step 5,094,026 | Avg Reward:    7.6 | Epsilon: 0.010 | Time: 0.2h
| Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,159,324 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.4h
# Step 5,160,236 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,161,072 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.4h
# Step 5,161,901 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,162,831 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,163,844 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,164,699 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,165,790 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,166,654 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.4h
# Step 5,167,538 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,168,479 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,169,310 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,170,364 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.4h
# Step 5,171,061 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.4h
# Step 5,172,098 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.4h
# Step 5,172,996 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.4h
# Step 5,173,749 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.4h
# Step 5,174,715 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,175,484 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,176,287 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.4h
# Step 5,177,028 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.4h
# Step 5,177,865 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.4h
# Step 5,178,891 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.4h
# Step 5,179,724 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.4h
# Step 5,180,594 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.4h
# Step 5,181,478 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,182,373 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,183,346 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,184,304 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,185,129 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,186,309 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,187,267 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,188,078 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,188,879 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.5h
# Step 5,189,735 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.5h
# Step 5,190,655 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.5h
# Step 5,191,416 | Avg Reward:    8.5 | Epsilon: 0.010 | Time: 0.5h
# Step 5,192,250 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.5h
# Step 5,193,028 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,194,049 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.5h
# Step 5,195,006 | Avg Reward:    8.5 | Epsilon: 0.010 | Time: 0.5h
# Step 5,195,691 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.5h
# Step 5,196,428 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.5h
# Step 5,197,193 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.5h
# Step 5,198,066 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,199,049 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,199,752 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# 💾 Checkpoint saved: /kaggle/working/checkpoint_5200000.pth
# Step 5,200,558 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,201,309 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,202,258 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,203,147 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,204,023 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,204,840 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,205,591 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,206,387 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,207,177 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,207,965 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,208,813 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,209,702 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,210,541 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,211,393 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,212,267 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,213,111 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,213,945 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,214,932 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,215,636 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.5h
# Step 5,216,516 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,217,400 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.5h
# Step 5,218,351 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.5h
# Step 5,219,451 | Avg Reward:    8.5 | Epsilon: 0.010 | Time: 0.5h
# Step 5,220,334 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.6h
# Step 5,221,202 | Avg Reward:    8.5 | Epsilon: 0.010 | Time: 0.6h
# Step 5,221,970 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.6h
# Step 5,222,816 | Avg Reward:    8.6 | Epsilon: 0.010 | Time: 0.6h
# Step 5,223,662 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.6h
# Step 5,224,458 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.6h
# Step 5,225,381 | Avg Reward:    8.7 | Epsilon: 0.010 | Time: 0.6h
# Step 5,226,174 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.6h
# Step 5,226,955 | Avg Reward:    8.8 | Epsilon: 0.010 | Time: 0.6h
# Step 5,227,694 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.6h
# Step 5,228,589 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.6h
# Step 5,229,497 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.6h
# Step 5,230,378 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.6h
# Step 5,231,170 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.6h
# Step 5,232,026 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.6h
# Step 5,232,867 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.6h
# Step 5,233,769 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,234,727 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,235,573 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,236,322 | Avg Reward:    9.2 | Epsilon: 0.010 | Time: 0.6h
# Step 5,237,248 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,238,012 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,238,850 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.6h
# Step 5,239,886 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.6h
# Step 5,240,567 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.6h
# Step 5,241,394 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.6h
# Step 5,242,330 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.6h
# Step 5,243,212 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.6h
# Step 5,244,183 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.6h
# Step 5,245,019 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.6h
# Step 5,245,807 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.6h
# Step 5,246,518 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.6h
# Step 5,247,227 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 0.6h
# Step 5,248,008 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 0.6h
# Step 5,248,750 | Avg Reward:   10.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,249,588 | Avg Reward:   10.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,250,394 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 0.6h
# Step 5,251,119 | Avg Reward:   10.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,251,882 | Avg Reward:   10.2 | Epsilon: 0.010 | Time: 0.6h
# Step 5,252,667 | Avg Reward:   10.2 | Epsilon: 0.010 | Time: 0.6h
# Step 5,253,498 | Avg Reward:   10.2 | Epsilon: 0.010 | Time: 0.6h
# Step 5,254,399 | Avg Reward:   10.2 | Epsilon: 0.010 | Time: 0.6h
# Step 5,255,229 | Avg Reward:   10.3 | Epsilon: 0.010 | Time: 0.6h
# Step 5,256,200 | Avg Reward:   10.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,257,037 | Avg Reward:   10.2 | Epsilon: 0.010 | Time: 0.6h
# Step 5,257,791 | Avg Reward:   10.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,258,617 | Avg Reward:   10.1 | Epsilon: 0.010 | Time: 0.6h
# Step 5,259,557 | Avg Reward:   10.2 | Epsilon: 0.010 | Time: 0.7h
# Step 5,260,539 | Avg Reward:   10.1 | Epsilon: 0.010 | Time: 0.7h
# Step 5,261,512 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.7h
# Step 5,262,391 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.7h
# Step 5,263,195 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.7h
# Step 5,263,973 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.7h
# Step 5,264,808 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.7h
# Step 5,265,690 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.7h
# Step 5,266,597 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.7h
# Step 5,267,623 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,268,646 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,269,642 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,270,530 | Avg Reward:    9.4 | Epsilon: 0.010 | Time: 0.7h
# Step 5,271,301 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,272,036 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.7h
# Step 5,272,813 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.7h
# Step 5,273,910 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,274,737 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,275,441 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,276,333 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.7h
# Step 5,277,181 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.7h
# Step 5,278,401 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,279,240 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.7h
# Step 5,280,044 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.7h
# Step 5,280,865 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.7h
# Step 5,281,867 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,282,694 | Avg Reward:    9.4 | Epsilon: 0.010 | Time: 0.7h
# Step 5,283,604 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,284,434 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,285,142 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.7h
# Step 5,286,120 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,287,007 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,287,782 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,288,702 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,289,415 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.7h
# Step 5,290,287 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.7h
# Step 5,291,446 | Avg Reward:    9.2 | Epsilon: 0.010 | Time: 0.7h
# Step 5,292,194 | Avg Reward:    9.2 | Epsilon: 0.010 | Time: 0.7h
# Step 5,293,049 | Avg Reward:    9.2 | Epsilon: 0.010 | Time: 0.7h
# Step 5,293,804 | Avg Reward:    9.2 | Epsilon: 0.010 | Time: 0.7h
# Step 5,294,528 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.7h
# Step 5,295,315 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.7h
# Step 5,296,135 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.7h
# Step 5,296,873 | Avg Reward:    9.4 | Epsilon: 0.010 | Time: 0.7h
# Step 5,297,697 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.8h
# Step 5,298,672 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.8h
# Step 5,299,403 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.8h
# 💾 Checkpoint saved: /kaggle/working/checkpoint_5300000.pth
# Step 5,300,209 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.8h
# Step 5,301,247 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.8h
# Step 5,302,247 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.8h
# Step 5,302,932 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.8h
# Step 5,303,672 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.8h
# Step 5,304,574 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.8h
# Step 5,305,347 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.8h
# Step 5,306,244 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.8h
# Step 5,307,171 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.8h
# Step 5,307,846 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.8h
# Step 5,308,769 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.8h
# Step 5,309,445 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.8h
# Step 5,310,183 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.8h
# Step 5,311,354 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.8h
# Step 5,312,080 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.8h
# Step 5,312,923 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.8h
# Step 5,313,735 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.8h
# Step 5,314,591 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.8h
# Step 5,315,381 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.8h
# Step 5,316,332 | Avg Reward:    9.4 | Epsilon: 0.010 | Time: 0.8h
# Step 5,317,081 | Avg Reward:    9.4 | Epsilon: 0.010 | Time: 0.8h
# Step 5,318,071 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.8h
# Step 5,318,953 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.8h
# Step 5,319,946 | Avg Reward:    9.2 | Epsilon: 0.010 | Time: 0.8h
# Step 5,320,748 | Avg Reward:    9.2 | Epsilon: 0.010 | Time: 0.8h
# Step 5,321,675 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.8h
# Step 5,322,578 | Avg Reward:    9.2 | Epsilon: 0.010 | Time: 0.8h
# Step 5,323,319 | Avg Reward:    9.2 | Epsilon: 0.010 | Time: 0.8h
# Step 5,324,279 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.8h
# Step 5,325,203 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.8h
# Step 5,325,984 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.8h
# Step 5,326,887 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.8h
# Step 5,327,659 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.8h
# Step 5,328,659 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.8h
# Step 5,329,605 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.8h
# Step 5,330,413 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.8h
# Step 5,331,189 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.8h
# Step 5,331,938 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.8h
# Step 5,332,759 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.8h
# Step 5,333,541 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.8h
# Step 5,334,348 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.8h
# Step 5,335,002 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.8h
# Step 5,335,753 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.8h
# Step 5,336,651 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,337,380 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,338,156 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.9h
# Step 5,338,906 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,339,843 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.9h
# Step 5,340,809 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,341,771 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.9h
# Step 5,342,620 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,343,524 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,344,366 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,345,298 | Avg Reward:    8.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,346,118 | Avg Reward:    9.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,346,936 | Avg Reward:    9.1 | Epsilon: 0.010 | Time: 0.9h
# Step 5,347,670 | Avg Reward:    9.2 | Epsilon: 0.010 | Time: 0.9h
# Step 5,348,520 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.9h
# Step 5,349,362 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.9h
# Step 5,350,211 | Avg Reward:    9.3 | Epsilon: 0.010 | Time: 0.9h
# Step 5,351,176 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 0.9h
# Step 5,352,013 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.9h
# Step 5,352,814 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 0.9h
# Step 5,353,600 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.9h
# Step 5,354,209 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.9h
# Step 5,355,223 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.9h
# Step 5,356,240 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.9h
# Step 5,357,056 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.9h
# Step 5,358,004 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 0.9h
# Step 5,358,872 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.9h
# Step 5,359,641 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,360,411 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,361,215 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.9h
# Step 5,362,025 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 0.9h
# Step 5,362,911 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,363,847 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,364,647 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,365,409 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,366,368 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,367,345 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,368,062 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,368,894 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,369,612 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,370,288 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,370,988 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,371,793 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 0.9h
# Step 5,372,647 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,373,340 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 0.9h
# Step 5,374,164 | Avg Reward:   10.2 | Epsilon: 0.010 | Time: 0.9h
# Step 5,374,887 | Avg Reward:   10.3 | Epsilon: 0.010 | Time: 1.0h
# Step 5,375,699 | Avg Reward:   10.3 | Epsilon: 0.010 | Time: 1
| Avg Reward:   10.2 | Epsilon: 0.010 | Time: 1.5h
# Step 5,602,776 | Avg Reward:   10.2 | Epsilon: 0.010 | Time: 1.5h
# Step 5,603,819 | Avg Reward:   10.1 | Epsilon: 0.010 | Time: 1.5h
# Step 5,604,761 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 1.5h
# Step 5,605,820 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.5h
# Step 5,606,656 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.5h
# Step 5,607,442 | Avg Reward:   10.1 | Epsilon: 0.010 | Time: 1.6h
# Step 5,608,443 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 1.6h
# Step 5,609,288 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 1.6h
# Step 5,610,147 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 1.6h
# Step 5,611,163 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.6h
# Step 5,612,096 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.6h
# Step 5,613,014 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.6h
# Step 5,613,804 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,614,589 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,615,394 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,616,279 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 1.6h
# Step 5,617,220 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 1.6h
# Step 5,618,048 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,618,677 | Avg Reward:    9.5 | Epsilon: 0.010 | Time: 1.6h
# Step 5,619,464 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,620,311 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,621,244 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,622,125 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,622,895 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.6h
# Step 5,623,815 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,624,799 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,625,685 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,626,605 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,627,411 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,628,172 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,629,105 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,630,032 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,630,795 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,631,608 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,632,569 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,633,412 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,634,183 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,635,020 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,635,887 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,636,673 | Avg Reward:    9.6 | Epsilon: 0.010 | Time: 1.6h
# Step 5,637,783 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,638,489 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,639,284 | Avg Reward:    9.7 | Epsilon: 0.010 | Time: 1.6h
# Step 5,640,090 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.6h
# Step 5,640,884 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.6h
# Step 5,641,795 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.6h
# Step 5,642,504 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.6h
# Step 5,643,237 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 1.6h
# Step 5,644,144 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 1.6h
# Step 5,644,944 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 1.6h
# Step 5,645,807 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 1.6h
# Step 5,646,734 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,647,421 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,648,204 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,648,921 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,649,807 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,650,609 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,651,503 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,652,579 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,653,349 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,654,273 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 1.7h
# Step 5,655,116 | Avg Reward:   10.0 | Epsilon: 0.010 | Time: 1.7h
# Step 5,656,057 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,657,097 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,658,071 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,658,872 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,659,724 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,660,577 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,661,515 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,662,330 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,663,137 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,663,913 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,664,809 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,665,694 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,666,528 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,667,177 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,668,154 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,668,969 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,669,820 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,670,687 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,671,399 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1.7h
# Step 5,672,239 | Avg Reward:    9.8 | Epsilon: 0.010 | Time: 1.7h
# Step 5,673,071 | Avg Reward:    9.9 | Epsilon: 0.010 | Time: 1
| Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.4h
# Step 7,888,056 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.4h
# Step 7,888,793 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.4h
# Step 7,889,752 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.4h
# Step 7,890,465 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.4h
# Step 7,891,285 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.4h
# Step 7,892,246 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.4h
# Step 7,893,163 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.4h
# Step 7,893,871 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.4h
# Step 7,894,688 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.4h
# Step 7,895,486 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.4h
# Step 7,896,357 | Avg Reward:   10.7 | Epsilon: 0.010 | Time: 7.4h
# Step 7,897,270 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.4h
# Step 7,898,121 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.4h
# Step 7,898,985 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,899,687 | Avg Reward:   10.6 | Epsilon: 0.010 | Time: 7.5h
# 💾 Checkpoint saved: /kaggle/working/checkpoint_7900000.pth
# Step 7,900,513 | Avg Reward:   10.8 | Epsilon: 0.010 | Time: 7.5h
# Step 7,901,366 | Avg Reward:   10.8 | Epsilon: 0.010 | Time: 7.5h
# Step 7,902,160 | Avg Reward:   10.8 | Epsilon: 0.010 | Time: 7.5h
# Step 7,902,961 | Avg Reward:   10.8 | Epsilon: 0.010 | Time: 7.5h
# Step 7,903,853 | Avg Reward:   10.8 | Epsilon: 0.010 | Time: 7.5h
# Step 7,904,722 | Avg Reward:   10.8 | Epsilon: 0.010 | Time: 7.5h
# Step 7,905,584 | Avg Reward:   10.7 | Epsilon: 0.010 | Time: 7.5h
# Step 7,906,345 | Avg Reward:   10.8 | Epsilon: 0.010 | Time: 7.5h
# Step 7,907,130 | Avg Reward:   10.7 | Epsilon: 0.010 | Time: 7.5h
# Step 7,907,938 | Avg Reward:   10.7 | Epsilon: 0.010 | Time: 7.5h
# Step 7,908,777 | Avg Reward:   10.8 | Epsilon: 0.010 | Time: 7.5h
# Step 7,909,627 | Avg Reward:   10.9 | Epsilon: 0.010 | Time: 7.5h
# Step 7,910,567 | Avg Reward:   10.9 | Epsilon: 0.010 | Time: 7.5h
# Step 7,911,308 | Avg Reward:   10.8 | Epsilon: 0.010 | Time: 7.5h
# Step 7,912,156 | Avg Reward:   10.8 | Epsilon: 0.010 | Time: 7.5h
# Step 7,913,165 | Avg Reward:   10.7 | Epsilon: 0.010 | Time: 7.5h
# Step 7,914,170 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,915,145 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,915,940 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,916,718 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,917,580 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,918,364 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,919,056 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,919,907 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,920,835 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,921,763 | Avg Reward:   10.4 | Epsilon: 0.010 | Time: 7.5h
# Step 7,922,768 | Avg Reward:   10.3 | Epsilon: 0.010 | Time: 7.5h
# Step 7,923,542 | Avg Reward:   10.3 | Epsilon: 0.010 | Time: 7.5h
# Step 7,924,396 | Avg Reward:   10.3 | Epsilon: 0.010 | Time: 7.5h
# Step 7,925,170 | Avg Reward:   10.3 | Epsilon: 0.010 | Time: 7.5h
# Step 7,926,003 | Avg Reward:   10.3 | Epsilon: 0.010 | Time: 7.5h
# Step 7,926,756 | Avg Reward:   10.4 | Epsilon: 0.010 | Time: 7.5h
# Step 7,927,530 | Avg Reward:   10.4 | Epsilon: 0.010 | Time: 7.5h
# Step 7,928,293 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,929,127 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,929,815 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,930,700 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7.5h
# Step 7,931,588 | Avg Reward:   10.5 | Epsilon: 0.010 | Time: 7
| Avg Reward:   10.9 | Epsilon: 0.010 | Time: 7.7h
# Step 7,994,795 | Avg Reward:   10.9 | Epsilon: 0.010 | Time: 7.7h
# Step 7,995,731 | Avg Reward:   11.0 | Epsilon: 0.010 | Time: 7.7h
# Step 7,996,636 | Avg Reward:   11.1 | Epsilon: 0.010 | Time: 7.7h
# Step 7,997,333 | Avg Reward:   11.1 | Epsilon: 0.010 | Time: 7.7h
# Step 7,998,315 | Avg Reward:   11.1 | Epsilon: 0.010 | Time: 7.7h
# Step 7,999,151 | Avg Reward:   11.1 | Epsilon: 0.010 | Time: 7.7h
# 💾 Checkpoint saved: /kaggle/working/checkpoint_8000000.pth
#
# ==================================================
# ✅ Training complete!
#    Final avg reward: 11.1
#    Model saved to: /kaggle/working/final_model.pth
# ==================================================

# %% [markdown]
# ## 📥 Step 9: View Output Files
#
# After training, find your model in the **Output** tab on the right panel.
# - `final_model.pth` - The trained model
# - `checkpoint_*.pth` - Intermediate checkpoints

# %%
# List saved files
import os
print("\n📁 Saved files in /kaggle/working:")
for f in os.listdir('/kaggle/working'):
    if f.endswith('.pth'):
        size_mb = os.path.getsize(f'/kaggle/working/{f}') / (1024*1024)
        print(f"  📄 {f} ({size_mb:.1f} MB)")
# Out:
# 📁 Saved files in /kaggle/working:
#   📄 checkpoint_5600000.pth (19.3 MB)
#   📄 checkpoint_8000000.pth (19.3 MB)
#   📄 checkpoint_7000000.pth (19.3 MB)
#   📄 checkpoint_7100000.pth (19.3 MB)
#   📄 checkpoint_7900000.pth (19.3 MB)
#   📄 checkpoint_6400000.pth (19.3 MB)
#   📄 checkpoint_5300000.pth (19.3 MB)
#   📄 checkpoint_6000000.pth (19.3 MB)
#   📄 final_model.pth (19.3 MB)
#   📄 checkpoint_7700000.pth (19.3 MB)
#   📄 checkpoint_6300000.pth (19.3 MB)
#   📄 checkpoint_5100000.pth (19.3 MB)
#   📄 checkpoint_6200000.pth (19.3 MB)
#   📄 checkpoint_5800000.pth (19.3 MB)
#   📄 checkpoint_5500000.pth (19.3 MB)
#   📄 checkpoint_7800000.pth (19.3 MB)
#   📄 checkpoint_7300000.pth (19.3 MB)
#   📄 checkpoint_6800000.pth (19.3 MB)
#   📄 checkpoint_7500000.pth (19.3 MB)
#   📄 checkpoint_5700000.pth (19.3 MB)
#   📄 checkpoint_5200000.pth (19.3 MB)
#   📄 checkpoint_7600000.pth (19.3 MB)
#   📄 checkpoint_7200000.pth (19.3 MB)
#   📄 checkpoint_6700000.pth (19.3 MB)
#   📄 checkpoint_6500000.pth (19.3 MB)
#   📄 checkpoint_6600000.pth (19.3 MB)
#   📄 checkpoint_7400000.pth (19.3 MB)
#   📄 checkpoint_6900000.pth (19.3 MB)
#   📄 checkpoint_5900000.pth (19.3 MB)
#   📄 checkpoint_5400000.pth (19.3 MB)
#   📄 checkpoint_6100000.pth (19.3 MB)

# %% [markdown]
# ---
#
# ## 🔧 Troubleshooting
#
# **If no GPU:**
# 1. Go to Settings → Accelerator → GPU T4 x2
# 2. Click "Save" and re-run all cells
#
# **If kernel restarts:**
# - Checkpoints are auto-saved every 50k steps
# - Just re-run all cells to resume from last checkpoint
#
# **Kaggle Session Limits:**
# - GPU sessions: 30 hours/week
# - Max runtime: 12 hours per session
